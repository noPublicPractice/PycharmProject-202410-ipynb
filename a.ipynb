# %%
import matplotlib.pyplot as plt
import json
import numpy as np
import shap

# %%
class const:
    label = 'CI'  # AF,AS,MI,CI
    label_ch = '脑梗'  # 房颤,动脉粥样硬化,心梗,脑梗
    folds = 6
    great_random_state = 15000
    model_name = 'LGBM'
    do_write_json_path___ = r'%s%s_shap_dict.json'

# %% [markdown]
# ## SHAP

# %%
def out_shap(data):
    print(f"Predicted Probability for Sample: {data['predicted_proba']:.2f}")  # 输出预测的概率值
    shap_dict = shap.Explanation(
            values=np.array(data["values"]),
            base_values=data["base_values"],
            data=np.array(data["data"]),
            feature_names=data["feature_names"]
        )
    shap.waterfall_plot(shap_dict)  # 使用 waterfall plot 来显示该样本的特征重要性
out_shap(json.load(open(const.do_write_json_path___ % ('房颤', 'AF'), 'r', encoding='utf-8')))
out_shap(json.load(open(const.do_write_json_path___ % ('动脉粥样硬化', 'AS'), 'r', encoding='utf-8')))
out_shap(json.load(open(const.do_write_json_path___ % ('心梗', 'MI'), 'r', encoding='utf-8')))
out_shap(json.load(open(const.do_write_json_path___ % ('脑梗', 'CI'), 'r', encoding='utf-8')))
# Out:
# Predicted Probability for Sample: 0.07
# Predicted Probability for Sample: 0.08
# Predicted Probability for Sample: 0.42
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[6], line 13
#      11 out_shap(json.load(open(const.do_write_json_path___ % ('动脉粥样硬化', 'AS'), 'r', encoding='utf-8')))
#      12 out_shap(json.load(open(const.do_write_json_path___ % ('心梗', 'MI'), 'r', encoding='utf-8')))
# ---> 13 out_shap(json.load(open(const.do_write_json_path___ % ('脑梗', 'CI'), 'r', encoding='utf-8')))
#
# File E:\Python\Miniconda3-py3.10.10_23.3.1\envs\1.4-数据绘图\lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
# ...
